# %% [markdown]
# ![NBA image.jpg](data:image/jpeg;base64,...)
# This Python program will analyze NBA player and season statistics beginning season year 1950. The main purpose of analyzing this NBA is to show unique player scoring trends. The data csv files were downloaded from www.kaggle.com.
# Data web link location: https://www.kaggle.com/datasets/drgilermo/nba-players-stats

# %% [markdown]
# Python code to read NBA csv files:
#
# Players.csv
# Seasons_Stats.csv
# player_data.csv

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Python code to read and clean data csv files for null or abstract values that can not be used. The data will be cleaned using pandas and numpy functions.

# %%
player_data = pd.read_csv('player_data.csv')
player_name = pd.read_csv('Players.csv')
season_stats = pd.read_csv('Seasons_Stats.csv')
season_stats.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...    FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %% [markdown]
# Remove unneeded data colunms and null undefined data from season stats. The season year is changed from a float value to an integer value:

# %%
seasonStats = season_stats.drop(columns=['GS', 'MP','G','FG','FGA','FG%','2P','2PA','2P%','PER','ORB','ORB%','3PAr','DRB','DRB%','TRB','TRB%','AST%','STL','STL%','BLK','BLK%','TOV','TOV%','TS%','USG%','blanl','blank2','WS','WS/48','OBPM','BPM','VORP','3P','3P%','3PA','DBPM','OWS','DWS','FTr','FT','FTA','FT%','PF','eFG%','AST'])

seasonStats = seasonStats.dropna()
seasonStats['Year'] = seasonStats['Year'].astype(int)
seasonStats['PTS'] = seasonStats['PTS'].astype(int)
seasonStats['Age'] = seasonStats['Age'].astype(int)

# %%
#seasonByYear = seasonStats.groupby('Year')
#['PTS'].max()
#seasonByYear.head()
seasonByYear = seasonStats.sort_values(by = 'Year')
seasonByYear.head()
# Out:
#      Unnamed: 0  Year           Player  Pos  Age   Tm  PTS
# 0             0  1950  Curly Armstrong  G-F   31  FTW  458
# 212         212  1950        Red Owens   SG   24  TOT  240
# 211         211  1950        Mac Otten  F-C   24  STB  103
# 210         210  1950        Mac Otten  F-C   24  TRI   39
# 209         209  1950        Mac Otten  F-C   24  TOT  142

# %%
seasonByYear.loc[seasonByYear['Year'] == 1963]
# Out:
#       Unnamed: 0  Year          Player Pos  Age   Tm   PTS
# 1898        1898  1963   Bevo Nordmann   C   23  TOT   371
# 1897        1897  1963    Paul Neumann  PG   25  SYR   655
# 1896        1896  1963     Don Nelson*  SF   22  CHZ   419
# 1895        1895  1963   Willie Naulls  SF   28  SFW   518
# 1899        1899  1963   Bevo Nordmann   C   23  STL    93
# ...          ...   ...             ...  ..  ...  ...   ...
# 1853        1853  1963        Si Green  PG   29  CHZ   853
# 1854        1854  1963      Hal Greer*  SG   26  SYR  1562
# 1855        1855  1963   Gene Guarilia  SF   25  BOS    26
# 1856        1856  1963  Richie Guerin*  SG   30  NYK  1701
# 1851        1851  1963       Tom Gola*  SF   30  NYK   624
#
# [133 rows x 7 columns]

# %%
seasonByYear.sort_values(by = 'PTS', ascending=False)
# Out:
#        Unnamed: 0  Year             Player Pos  Age   Tm   PTS
# 1706         1706  1962  Wilt Chamberlain*   C   25  PHW  4029
# 1827         1827  1963  Wilt Chamberlain*   C   26  SFW  3586
# 8469         8469  1987    Michael Jordan*  SG   23  CHI  3041
# 1593         1593  1961  Wilt Chamberlain*   C   24  PHW  3033
# 1962         1962  1964  Wilt Chamberlain*   C   27  SFW  2948
# ...           ...   ...                ...  ..  ...  ...   ...
# 14674       14674  2000         Derek Hood  PF   23  CHH     0
# 12505       12505  1996       Donald Hodge   C   26  CHH     0
# 12532       12532  1996        Tim Kempton  PF   32  ATL     0
# 17840       17840  2006           Deng Gai   C   23  PHI     0
# 16128       16128  2003       Chris Dudley   C   37  POR     0
#
# [24616 rows x 7 columns]

# %%
pointSort = seasonByYear.sort_values(by = 'PTS')
pointSort.head()
# Out:
#        Unnamed: 0  Year           Player Pos  Age   Tm  PTS
# 15893       15893  2002  Norm Richardson  SG   22  IND    0
# 13326       13326  1997   Elmore Spencer   C   27  SEA    0
# 17106       17106  2005    Maurice Baker  PG   25  POR    0
# 17105       17105  2005    Maurice Baker  PG   25  LAC    0
# 17104       17104  2005    Maurice Baker  PG   25  TOT    0

# %%
sortedYears = seasonByYear.sort_values(by = 'Year', ascending=False)
sortedYears.sort_values(by = 'PTS', ascending = False)
# Out:
#        Unnamed: 0  Year             Player Pos  Age   Tm   PTS
# 1706         1706  1962  Wilt Chamberlain*   C   25  PHW  4029
# 1827         1827  1963  Wilt Chamberlain*   C   26  SFW  3586
# 8469         8469  1987    Michael Jordan*  SG   23  CHI  3041
# 1593         1593  1961  Wilt Chamberlain*   C   24  PHW  3033
# 1962         1962  1964  Wilt Chamberlain*   C   27  SFW  2948
# ...           ...   ...                ...  ..  ...  ...   ...
# 15575       15575  2002        Randy Brown  PG   33  BOS     0
# 1129         1129  1957        Forest Able   G   24  SYR     0
# 17787       17787  2006         Josh Davis  PF   25  HOU     0
# 23924       23924  2016       J.J. O'Brien  SF   23  UTA     0
# 13598       13598  1998        Jeff Grayer  SG   32  CHH     0
#
# [24616 rows x 7 columns]

# %%
seasonPlot = seasonByYear.groupby("Year").max()
seasonPlot.head()
# Out:
#       Unnamed: 0          Player Pos  Age   Tm   PTS
# Year
# 1950         311      Whitey Von  SG   36  WSC  1865
# 1951         486  Warren Perkins  SG   33  WSC  1932
# 1952         617   Zeke Sinicola  SG   34  TOT  1674
# 1953         778    Zeke Zawoluk  SG   35  TOT  1564
# 1954         910    Zeke Zawoluk  SG   38  TOT  1759

# %%
seasonByYear[['Player','Pos','Age' ,'Tm', 'PTS']].describe()
# Out:
#                 Age           PTS
# count  24616.000000  24616.000000
# mean      26.664405    510.255606
# std        3.841892    492.940404
# min       18.000000      0.000000
# 25%       24.000000    106.000000
# 50%       26.000000    364.000000
# 75%       29.000000    778.000000
# max       44.000000   4029.000000

# %%
plot = seasonPlot.plot.bar(x='Player', y='PTS', rot=0)

# %%
sortedYears.groupby("PTS").max()
# Out:
#       Unnamed: 0  Year             Player Pos  Age   Tm
# PTS
# 0          24623  2017         Yinka Dare  SG   39  WSB
# 1          24447  2017    Zendon Hamilton  SG   38  WSB
# 2          24620  2017      Zeke Sinicola  SG   37  WSB
# 3          24607  2017       Travis Grant  SG   37  WSB
# 4          24572  2017      Willie Burton  SG   39  WSB
# ...          ...   ...                ...  ..  ...  ...
# 2948        1962  1964  Wilt Chamberlain*   C   27  SFW
# 3033        1593  1961  Wilt Chamberlain*   C   24  PHW
# 3041        8469  1987    Michael Jordan*  SG   23  CHI
# 3586        1827  1963  Wilt Chamberlain*   C   26  SFW
# 4029        1706  1962  Wilt Chamberlain*   C   25  PHW
#
# [2117 rows x 6 columns]

# %%
sortedYears.query('Year')
# Out:
#       Unnamed: 0  Year        Player Pos  Age   Tm  PTS
# 2017        2017  1964  Rudy LaRusso  PF   26  LAL  972
# 2017        2017  1964  Rudy LaRusso  PF   26  LAL  972
# 2017        2017  1964  Rudy LaRusso  PF   26  LAL  972
# 2017        2017  1964  Rudy LaRusso  PF   26  LAL  972
# 2017        2017  1964  Rudy LaRusso  PF   26  LAL  972
# ...          ...   ...           ...  ..  ...  ...  ...
# 1950        1950  1964    Al Bianchi  PG   31  PHI  623
# 1950        1950  1964    Al Bianchi  PG   31  PHI  623
# 1950        1950  1964    Al Bianchi  PG   31  PHI  623
# 1950        1950  1964    Al Bianchi  PG   31  PHI  623
# 1950        1950  1964    Al Bianchi  PG   31  PHI  623
#
# [24616 rows x 7 columns]

# %% [markdown]
# Create a tuple for each season and load every player into the tuple that is listed for that season.

# %%
for player in seasonStats:
# Out:
# 0        1950
# 1        1950
# 2        1950
# 3        1950
# 4        1950
#          ...
# 24686    2017
# 24687    2017
# 24688    2017
# 24689    2017
# 24690    2017
# Name: Year, Length: 24616, dtype: int32

# %%
#for player in seasonStats:
# for seasonStats['Year'] 
#seasonYear(player) = 
#seasonStats.query('Year == 1950')
seasonYears = seasonStats.sort_values(by = 'Year')
seasonYears
seasonYearsPoints = seasonYears.sort_values(by = 'PTS', ascending=False)
seasonYearsPoints
# Out:
#        Unnamed: 0  Year             Player Pos  Age   Tm   PTS
# 1706         1706  1962  Wilt Chamberlain*   C   25  PHW  4029
# 1827         1827  1963  Wilt Chamberlain*   C   26  SFW  3586
# 8469         8469  1987    Michael Jordan*  SG   23  CHI  3041
# 1593         1593  1961  Wilt Chamberlain*   C   24  PHW  3033
# 1962         1962  1964  Wilt Chamberlain*   C   27  SFW  2948
# ...           ...   ...                ...  ..  ...  ...   ...
# 14674       14674  2000         Derek Hood  PF   23  CHH     0
# 12505       12505  1996       Donald Hodge   C   26  CHH     0
# 12532       12532  1996        Tim Kempton  PF   32  ATL     0
# 17840       17840  2006           Deng Gai   C   23  PHI     0
# 16128       16128  2003       Chris Dudley   C   37  POR     0
#
# [24616 rows x 7 columns]

# %%
player_data.head()
# Out:
#                   name  year_start  year_end position height  weight  \
# 0       Alaa Abdelnaby        1991      1995      F-C   6-10   240.0
# 1      Zaid Abdul-Aziz        1969      1978      C-F    6-9   235.0
# 2  Kareem Abdul-Jabbar        1970      1989        C    7-2   225.0
# 3   Mahmoud Abdul-Rauf        1991      2001        G    6-1   162.0
# 4    Tariq Abdul-Wahad        1998      2003        F    6-6   223.0
#
#          birth_date                                college
# 0     June 24, 1968                        Duke University
# 1     April 7, 1946                  Iowa State University
# 2    April 16, 1947  University of California, Los Angeles
# 3     March 9, 1969             Louisiana State University
# 4  November 3, 1974              San Jose State University

# %%
player_name.head()
# Out:
#    Unnamed: 0           Player  height  weight  \
# 0           0  Curly Armstrong   180.0    77.0
# 1           1     Cliff Barker   188.0    83.0
# 2           2    Leo Barnhorst   193.0    86.0
# 3           3       Ed Bartels   196.0    88.0
# 4           4      Ralph Beard   178.0    79.0
#
#                            collage    born   birth_city birth_state
# 0               Indiana University  1918.0          NaN         NaN
# 1           University of Kentucky  1921.0     Yorktown     Indiana
# 2         University of Notre Dame  1924.0          NaN         NaN
# 3  North Carolina State University  1925.0          NaN         NaN
# 4           University of Kentucky  1927.0  Hardinsburg    Kentucky

# %% [markdown]
# For loop that sorts each season by year, then sorts each player by total points for that season. The top 2 players for each season are displayed in a dataframe.

# %%
for year in range(1950,2018): 
    currentYear = seasonByYear.loc[seasonByYear['Year'] == year]
    pointSort = currentYear.sort_values(by = 'PTS', ascending=False)
    print(pointSort.iloc[[0, 1], [1, 2, 3, 4, 5, 6]])
# Out:
#      Year         Player Pos  Age   Tm   PTS
# 172  1950  George Mikan*   C   25  MNL  1865
# 84   1950     Alex Groza   C   23  INO  1496
#      Year         Player Pos  Age   Tm   PTS
# 428  1951  George Mikan*   C   26  MNL  1932
# 369  1951     Alex Groza   C   24  INO  1429
#      Year         Player Pos  Age   Tm   PTS
# 488  1952   Paul Arizin*  SF   23  PHW  1674
# 565  1952  George Mikan*   C   27  MNL  1523
#      Year          Player Pos  Age   Tm   PTS
# 679  1953  Neil Johnston*   C   23  PHW  1564
# 716  1953   George Mikan*   C   28  MNL  1442
#      Year          Player Pos  Age   Tm   PTS
# 831  1954  Neil Johnston*   C   24  PHW  1759
# 798  1954      Bob Cousy*  PG   25  BOS  1383
#      Year          Player Pos  Age   Tm   PTS
# 956  1955  Neil Johnston*   C   25  PHW  1631
# 913  1955    Paul Arizin*  SF   26  PHW  1512
#       Year        Player Pos  Age   Tm   PTS
# 1095  1956   Bob Pettit*   C   23  STL  1849
# 1022  1956  Paul Arizin*  SF   27  PHW  1741
# ...

# %% [markdown]
# Each player in the list will be put into its own tuple. The top 2 players scoring averages for each season will be put into a list or tuple. Functions will be done to analyze top 2 players scoring average for each season since 1950. Mean and median values will be calculated using functions.

# %%
playerData = pd.DataFrame(seasonStats, columns = ['Year','Player','Pos','Age','Tm','PTS'])
playerData
playerDatalib = playerData.to_dict('index')
#playerDatalib
for player in playerDatalib:
    print(playerDatalib[player])
#for x in range(len(playerData)):
    #print(playerData[x])
    #for y in range(1950, 2017):
#print(type(playerData))
#print(playerData.head)
# Out:
# {'Year': 1950, 'Player': 'Curly Armstrong', 'Pos': 'G-F', 'Age': 31.0, 'Tm': 'FTW', 'PTS': 458.0}
# {'Year': 1950, 'Player': 'Cliff Barker', 'Pos': 'SG', 'Age': 29.0, 'Tm': 'INO', 'PTS': 279.0}
# {'Year': 1950, 'Player': 'Leo Barnhorst', 'Pos': 'SF', 'Age': 25.0, 'Tm': 'CHS', 'PTS': 438.0}
# {'Year': 1950, 'Player': 'Ed Bartels', 'Pos': 'F', 'Age': 24.0, 'Tm': 'TOT', 'PTS': 63.0}
# {'Year': 1950, 'Player': 'Ed Bartels', 'Pos': 'F', 'Age': 24.0, 'Tm': 'DNN', 'PTS': 59.0}
# {'Year': 1950, 'Player': 'Ed Bartels', 'Pos': 'F', 'Age': 24.0, 'Tm': 'NYK', 'PTS': 4.0}
# {'Year': 1950, 'Player': 'Ralph Beard', 'Pos': 'G', 'Age': 22.0, 'Tm': 'INO', 'PTS': 895.0}
# {'Year': 1950, 'Player': 'Gene Berce', 'Pos': 'G-F', 'Age': 23.0, 'Tm': 'TRI', 'PTS': 10.0}
# {'Year': 1950, 'Player': 'Charlie Black', 'Pos': 'F-C', 'Age': 28.0, 'Tm': 'TOT', 'PTS': 661.0}
# {'Year': 1950, 'Player': 'Charlie Black', 'Pos': 'F-C', 'Age': 28.0, 'Tm': 'FTW', 'PTS': 382.0}
# ...

# %% [markdown]
# Python code will put each season in its own dictionary. The code will be ran to determine the top 2 scorers for each NBA season dating back from 1950. The top 2 scorers for each season since 1950 will be put into either a list or tuple. Code will also calculate top scorers of the NBA seasons since 1950 and the year of top, median, and mean scoring averages.

# %% [markdown]
# Graph using matlabplot to make 3 different graphs. The first graph will display the top scoring average player for each season since 1950. The second graph will display the second top scorer average player for each NBA season. The third graph will display mean, median, and average top scorer average from NBA seasons starting from 1950. All graphs should have 50 players scoring average plotted.

# %% [markdown]
# Code to display 3 graphs of top and second top scorers in the NBA since 1950 and top scorers average, mean, and median plots of all top scorers since 1950.
