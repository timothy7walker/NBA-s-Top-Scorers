# %% [markdown]
# ![NBA image.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# The following libraries are used in this project. They needed libraries are imported.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Python code to read NBA csv file:
#
# Seasons_Stats.csv
#
# The Season_Stats.csv is the data file used in this analysis. The 'Seasons_Stats.csv' file contains all season year, player, name, position, team, and point total for each season.
#
# The raw data is displayed below with some 'NaN' values starting with the first rows.

# %%
season_stats = pd.read_csv(C)
season_stats.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...    FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %% [markdown]
# The Seasons_Stats.csv file is analyzed for null or abstract values that can not be used. The data is cleaned, condensed, and formated using pandas and numpy functions. Unneeded statistic column categories are removed from the data frame. Null undefined data (NaN) is also removed from season stats data frame. The season year, player point total, and player age are changed from a float value to an integer value:

# %%
seasonStats = season_stats.drop(columns=['GS', 'MP','G','FG','FGA','FG%','2P','2PA','2P%','PER','ORB','ORB%','3PAr','DRB','DRB%','TRB','TRB%','AST%','STL','STL%','BLK','BLK%','TOV','TOV%','TS%','USG%','blanl','blank2','WS','WS/48','OBPM','BPM','VORP','3P','3P%','3PA','DBPM','OWS','DWS','FTr','FT','FTA','FT%','PF','eFG%','AST'])

seasonStats = seasonStats.dropna()
seasonStats['Year'] = seasonStats['Year'].astype(int)
seasonStats['PTS'] = seasonStats['PTS'].astype(int)
seasonStats['Age'] = seasonStats['Age'].astype(int)

# %% [markdown]
# All players from seasons 1950 - 2017 are put into a dictionary. (The code is commented out do to library size. The code is commented out to reduce time it takes to to run the code and condense the data results.) This project analysis does not need the data to be put into a dictionary to complete top 2 scorer by season analysis. The code is only to show how the player data can be put into a dictionary for other anaylsis purposes.

# %%
#playerData = pd.DataFrame(seasonStats, columns = ['Year','Player','Pos','Age','Tm','PTS'])
#playerDatalib = playerData.to_dict('index')

# %% [markdown]
# After removing unneeded data columns, null, void values, the data is sorted by year 1950 to 2017. All players with complete statistics for the categories, player ('Player'), position ('Pos'), age ('Age'), team ('Tm'), and points ('PTS') are displayed and  sorted by year 1950 - 2017.

# %%
seasonByYear = seasonStats.sort_values(by = 'Year')
seasonByYear.head()
# Out:
#      Unnamed: 0  Year           Player  Pos  Age   Tm  PTS
# 0             0  1950  Curly Armstrong  G-F   31  FTW  458
# 212         212  1950        Red Owens   SG   24  TOT  240
# 211         211  1950        Mac Otten  F-C   24  STB  103
# 210         210  1950        Mac Otten  F-C   24  TRI   39
# 209         209  1950        Mac Otten  F-C   24  TOT  142

# %% [markdown]
# The code below, tests to show that player statistics are displayed for 1 specific season. The test season is 1963. This code will be used to sort all players by season year played. The goal is to display players statistic for each season, 1950 - 2017.

# %%
seasonByYear.loc[seasonByYear['Year'] == 1963]
# Out:
#       Unnamed: 0  Year          Player Pos  Age   Tm   PTS
# 1898        1898  1963   Bevo Nordmann   C   23  TOT   371
# 1897        1897  1963    Paul Neumann  PG   25  SYR   655
# 1896        1896  1963     Don Nelson*  SF   22  CHZ   419
# 1895        1895  1963   Willie Naulls  SF   28  SFW   518
# 1899        1899  1963   Bevo Nordmann   C   23  STL    93
# ...          ...   ...             ...  ..  ...  ...   ...
# 1853        1853  1963        Si Green  PG   29  CHZ   853
# 1854        1854  1963      Hal Greer*  SG   26  SYR  1562
# 1855        1855  1963   Gene Guarilia  SF   25  BOS    26
# 1856        1856  1963  Richie Guerin*  SG   30  NYK  1701
# 1851        1851  1963       Tom Gola*  SF   30  NYK   624
#
# [133 rows x 7 columns]

# %% [markdown]
# The data below uses the sort values function to organize the top scorers. The top scorers are organized from most to least points scored for all season years 1950 - 2017. This code organizes all players from all seasons 1950 -2017 in the data file and displays each player by point total highest to lowest. This data will be represented in a scatter point graph.

# %%
allPlayers = seasonByYear.sort_values(by = 'PTS', ascending = False)
allPlayers
# Out:
#        Unnamed: 0  Year             Player Pos  Age   Tm   PTS
# 1706         1706  1962  Wilt Chamberlain*   C   25  PHW  4029
# 1827         1827  1963  Wilt Chamberlain*   C   26  SFW  3586
# 8469         8469  1987    Michael Jordan*  SG   23  CHI  3041
# 1593         1593  1961  Wilt Chamberlain*   C   24  PHW  3033
# 1962         1962  1964  Wilt Chamberlain*   C   27  SFW  2948
# ...           ...   ...                ...  ..  ...  ...   ...
# 14674       14674  2000         Derek Hood  PF   23  CHH     0
# 12505       12505  1996       Donald Hodge   C   26  CHH     0
# 12532       12532  1996        Tim Kempton  PF   32  ATL     0
# 17840       17840  2006           Deng Gai   C   23  PHI     0
# 16128       16128  2003       Chris Dudley   C   37  POR     0
#
# [24616 rows x 7 columns]

# %% [markdown]
# All NBA scores scatterpoint graph.

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=allPlayers,x='Year',y='PTS')
plt.title('NBA All players scores 1950 - 2017') #title
plt.xlabel('Season Year') #x label
plt.ylabel('Points Scored') #y label
plt.show()

# %% [markdown]
# The code below displays statistical information about the player and points scored. This analysis is based on all players for all seasons, 1950 - 2017. The data is based on player age and points scored in a single season.
#
# Data breakdown:
#     total player count: 24,616.
#     Mean age: 26.66 (27)
#     Mean points scored per season: 510.26
#     Age standard deviation: 3.841892
#     Age point standard deviation: 492.940404
#     Minimum player age: 18
#     Minimum point scored in a season: 0
#     Age @ 25% data: 24
#     Points @ 25% data: 106
#     Age @ 50% data: 26
#     Points @ 50% data: 364
#     Age @ 75% data: 29
#     Points @ 75% data: 778
#     Max age: 44
#     Max points scored in a season: 4029

# %%
seasonByYear[['Age' ,'PTS']].describe()
# Out:
#                 Age           PTS
# count  24616.000000  24616.000000
# mean      26.664405    510.255606
# std        3.841892    492.940404
# min       18.000000      0.000000
# 25%       24.000000    106.000000
# 50%       26.000000    364.000000
# 75%       29.000000    778.000000
# max       44.000000   4029.000000

# %% [markdown]
# The code below sorts the player by each season, 1950 - 2017, and displays the top 2 scorers for each season 1950 - 2017.

# %%
seasonTopScorer = []
seasonTopScorer2 = []
for year in range(1950,2018): 
    currentYear = seasonByYear.loc[seasonByYear['Year'] == year]
    pointSort = currentYear.sort_values(by = 'PTS', ascending=False)
    seasonTopScorer.append(pointSort.iloc[[0]])
    seasonTopScorer2.append(pointSort.iloc[[1]])
    print(pointSort.iloc[[0]])
    print(pointSort.iloc[[1]])
# Out:
#      Unnamed: 0  Year         Player Pos  Age   Tm   PTS
# 172         172  1950  George Mikan*   C   25  MNL  1865
#     Unnamed: 0  Year      Player Pos  Age   Tm   PTS
# 84          84  1950  Alex Groza   C   23  INO  1496
#      Unnamed: 0  Year         Player Pos  Age   Tm   PTS
# 428         428  1951  George Mikan*   C   26  MNL  1932
#      Unnamed: 0  Year      Player Pos  Age   Tm   PTS
# 369         369  1951  Alex Groza   C   24  INO  1429
#      Unnamed: 0  Year        Player Pos  Age   Tm   PTS
# 488         488  1952  Paul Arizin*  SF   23  PHW  1674
#      Unnamed: 0  Year         Player Pos  Age   Tm   PTS
# 565         565  1952  George Mikan*   C   27  MNL  1523
#      Unnamed: 0  Year          Player Pos  Age   Tm   PTS
# 679         679  1953  Neil Johnston*   C   23  PHW  1564
#      Unnamed: 0  Year         Player Pos  Age   Tm   PTS
# 716         716  1953  George Mikan*   C   28  MNL  1442
#      Unnamed: 0  Year          Player Pos  Age   Tm   PTS
# ...

# %% [markdown]
# A compression is made to the top scorer data list previously, to list all players in a new list(topScorers) with 1 column category for all players.

# %%
topScorers = pd.concat(seasonTopScorer)
topScorers
# Out:
#        Unnamed: 0  Year             Player Pos  Age   Tm   PTS
# 172           172  1950      George Mikan*   C   25  MNL  1865
# 428           428  1951      George Mikan*   C   26  MNL  1932
# 488           488  1952       Paul Arizin*  SF   23  PHW  1674
# 679           679  1953     Neil Johnston*   C   23  PHW  1564
# 831           831  1954     Neil Johnston*   C   24  PHW  1759
# ...           ...   ...                ...  ..  ...  ...   ...
# 21827       21827  2013       Kevin Durant  SF   24  OKC  2280
# 22438       22438  2014       Kevin Durant  SF   25  OKC  2593
# 23114       23114  2015       James Harden  SG   25  HOU  2217
# 23722       23722  2016       James Harden  SG   26  HOU  2376
# 24654       24654  2017  Russell Westbrook  PG   28  OKC  2558
#
# [68 rows x 7 columns]

# %% [markdown]
# A compression is made to the 2nd top scorer data list previously, to list all players in a new list (topScorers2) with 1 column category for all players.

# %%
topScorers2 = pd.concat(seasonTopScorer2)
topScorers2
# Out:
#        Unnamed: 0  Year           Player Pos  Age   Tm   PTS
# 84             84  1950       Alex Groza   C   23  INO  1496
# 369           369  1951       Alex Groza   C   24  INO  1429
# 565           565  1952    George Mikan*   C   27  MNL  1523
# 716           716  1953    George Mikan*   C   28  MNL  1442
# 798           798  1954       Bob Cousy*  PG   25  BOS  1383
# ...           ...   ...              ...  ..  ...  ...   ...
# 21757       21757  2013      Kobe Bryant  SG   34  LAL  2133
# 22278       22278  2014  Carmelo Anthony  PF   29  NYK  2112
# 23000       23000  2015    Stephen Curry  PG   26  GSW  1900
# 23633       23633  2016    Stephen Curry  PG   27  GSW  2375
# 24306       24306  2017     James Harden  PG   27  HOU  2356
#
# [68 rows x 7 columns]

# %% [markdown]
# NBA top scores for each season 1950 - 2017 scatterplot:

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=topScorers,x='Year',y='PTS')
plt.title('NBA top Scorers 1950 - 2017') #title
plt.xlabel('Season Year') #x label
plt.ylabel('Points Scored') #y label
plt.show()

# %% [markdown]
# NBA 2nd top scores for each season 1950 - 2017 scatterplot:

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=topScorers2,x='Year',y='PTS')
plt.title('NBA Runner up top scorers 1950 - 2017') #title
plt.xlabel('Season Year') #x label
plt.ylabel('Points Scored') #y label
plt.show()
